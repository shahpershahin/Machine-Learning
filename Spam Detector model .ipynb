# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('message.csv',encoding='latin-1')

# %%
df.describe()
# Out:
#         Unnamed: 0       Nature     num_char     num_word     num_sent
# count  5169.000000  5169.000000  5169.000000  5169.000000  5169.000000
# mean   2734.699362     0.126330    78.977945    18.453279     1.947185
# std    1613.241267     0.332253    58.236293    13.324793     1.362406
# min       0.000000     0.000000     2.000000     1.000000     1.000000
# 25%    1331.000000     0.000000    36.000000     9.000000     1.000000
# 50%    2703.000000     0.000000    60.000000    15.000000     1.000000
# 75%    4129.000000     0.000000   117.000000    26.000000     2.000000
# max    5571.000000     1.000000   910.000000   220.000000    28.000000

# %%
df.head()
# Out:
#    Unnamed: 0  Nature                                            Message  \
# 0           0       0  Go until jurong point, crazy.. Available only ...
# 1           1       0                      Ok lar... Joking wif u oni...
# 2           2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3       0  U dun say so early hor... U c already then say...
# 4           4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_char  num_word  num_sent  \
# 0       111        24         2
# 1        29         8         2
# 2       155        37         2
# 3        49        13         1
# 4        61        15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
df.head()
# Out:
#    Unnamed: 0  Nature                                            Message  \
# 0           0       0  Go until jurong point, crazy.. Available only ...
# 1           1       0                      Ok lar... Joking wif u oni...
# 2           2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3       0  U dun say so early hor... U c already then say...
# 4           4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_char  num_word  num_sent  \
# 0       111        24         2
# 1        29         8         2
# 2       155        37         2
# 3        49        13         1
# 4        61        15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from sklearn import preprocessing
enc = preprocessing.LabelEncoder()

# %%
df['Nature']=enc.fit_transform(df['Nature'])

## 0= ham
## 1= spam

# %%
df.head()
# Out:
#    Unnamed: 0  Nature                                            Message  \
# 0           0       0  Go until jurong point, crazy.. Available only ...
# 1           1       0                      Ok lar... Joking wif u oni...
# 2           2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3       0  U dun say so early hor... U c already then say...
# 4           4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_char  num_word  num_sent  \
# 0       111        24         2
# 1        29         8         2
# 2       155        37         2
# 3        49        13         1
# 4        61        15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Nature              0
# Message             0
# num_char            0
# num_word            0
# num_sent            0
# transformed_text    9
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df=df.drop_duplicates(keep ='first')

# %%
df.shape
# Out:
# (5169, 7)

# %%
##EDA

# %%
ham_spam_ratio=df['Nature'].value_counts()
ham_spam_ratio
# Out:
# 0    4516
# 1     653
# Name: Nature, dtype: int64

# %%
ham_spam_pie_chart=plt.pie(ham_spam_ratio,labels=['ham','spam'],autopct="%0.2f")

# %%
#!pip install nltk

# %%
import nltk

# %%
#nltk.download('punkt')

# %%
## number of character in each message

df['num_char']=df['Message'].apply(len)

# %%
df.head()
# Out:
#    Unnamed: 0  Nature                                            Message  \
# 0           0       0  Go until jurong point, crazy.. Available only ...
# 1           1       0                      Ok lar... Joking wif u oni...
# 2           2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3       0  U dun say so early hor... U c already then say...
# 4           4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_char  num_word  num_sent  \
# 0       111        24         2
# 1        29         8         2
# 2       155        37         2
# 3        49        13         1
# 4        61        15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
## number of word in each message

df['num_word']=df['Message'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    Unnamed: 0  Nature                                            Message  \
# 0           0       0  Go until jurong point, crazy.. Available only ...
# 1           1       0                      Ok lar... Joking wif u oni...
# 2           2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3       0  U dun say so early hor... U c already then say...
# 4           4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_char  num_word  num_sent  \
# 0       111        24         2
# 1        29         8         2
# 2       155        37         2
# 3        49        13         1
# 4        61        15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
## number of sentences in each message

df['num_sent']=df['Message'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    Unnamed: 0  Nature                                            Message  \
# 0           0       0  Go until jurong point, crazy.. Available only ...
# 1           1       0                      Ok lar... Joking wif u oni...
# 2           2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3       0  U dun say so early hor... U c already then say...
# 4           4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_char  num_word  num_sent  \
# 0       111        24         2
# 1        29         8         2
# 2       155        37         2
# 3        49        13         1
# 4        61        15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
df[['num_char','num_word','num_sent']].describe()
# Out:
#           num_char     num_word     num_sent
# count  5169.000000  5169.000000  5169.000000
# mean     79.186883    18.454246     1.948152
# std      58.380576    13.325668     1.363792
# min       2.000000     1.000000     1.000000
# 25%      36.000000     9.000000     1.000000
# 50%      61.000000    15.000000     1.000000
# 75%     117.000000    26.000000     2.000000
# max     910.000000   220.000000    28.000000

# %%
#ham messages

df[df['Nature']==0][['num_char','num_word','num_sent']].describe()
# Out:
#           num_char     num_word     num_sent
# count  4516.000000  4516.000000  4516.000000
# mean     70.575952    17.120903     1.799601
# std      56.396321    13.493725     1.278465
# min       2.000000     1.000000     1.000000
# 25%      34.000000     8.000000     1.000000
# 50%      52.000000    13.000000     1.000000
# 75%      90.000000    22.000000     2.000000
# max     910.000000   220.000000    28.000000

# %%
#spam messages

df[df['Nature']==1][['num_char','num_word','num_sent']].describe()
# Out:
#          num_char    num_word    num_sent
# count  653.000000  653.000000  653.000000
# mean   138.738132   27.675345    2.975498
# std     30.418104    7.011513    1.487993
# min     13.000000    2.000000    1.000000
# 25%    132.000000   25.000000    2.000000
# 50%    149.000000   29.000000    3.000000
# 75%    158.000000   32.000000    4.000000
# max    226.000000   46.000000    8.000000

# %%
sns.pairplot(df,hue='Nature')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
## DATA PREPROCESSING

# %%
#nltk.download('stopwords')

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
stopwords
# Out:
# <WordListCorpusReader in '/Users/shahpershahin/nltk_data/corpora/stopwords'>

# %%
from nltk.stem.porter import PorterStemmer

ps =PorterStemmer()
ps.stem('working')
# Out:
# 'work'

# %%
def transform_Message(Message):
    Message=Message.lower()
    Message=nltk.word_tokenize(Message)
    
    y=[]
    for i in Message:
        if i.isalnum():
            y.append(i)
    Message=y[:]
    y.clear()
    
    for i in Message:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    Message=y[:]
    y.clear()
    
    for i in Message:
        y.append(ps.stem(i));
        
    
    return " ".join(y)

# %%
transform_Message("I love writing code for machine learning.")
# Out:
# 'love write code machin learn'

# %%
df['transformed_text']=df['Message'].apply(transform_Message)

# %%
df.head()
# Out:
#    Unnamed: 0  Nature                                            Message  \
# 0           0       0  Go until jurong point, crazy.. Available only ...
# 1           1       0                      Ok lar... Joking wif u oni...
# 2           2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           3       0  U dun say so early hor... U c already then say...
# 4           4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_char  num_word  num_sent  \
# 0       111        24         2
# 1        29         8         2
# 2       155        37         2
# 3        49        13         1
# 4        61        15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
# # !pip install wordcloud

# %%
from wordcloud import WordCloud

wc= WordCloud(width=2000,height=2000,min_font_size=10,background_color='white',max_words=10)

# %%
spam_wc=wc.generate(df[df['Nature']==1]['transformed_text'].str.cat( sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['Nature']==0]['transformed_text'].str.cat( sep=" "))

# %%
# Create a figure with a size of 30x10
plt.figure(figsize=(30, 10))

# Plot the ham_wc image
plt.imshow(ham_wc)

# %%
spam_words=[]

for msg in df[df['Nature']==1]['transformed_text'].tolist():
    for word in msg.split():
        spam_words.append(word)

# %%
len(spam_words)
# Out:
# 9936

# %%
from collections import Counter 
spam_words_df=pd.DataFrame(Counter(spam_words).most_common(30))

# %%
spam_words_df
# Out:
#           0    1
# 0      call  320
# 1      free  191
# 2         2  155
# 3       txt  141
# 4      text  122
# 5         u  119
# 6        ur  119
# 7     mobil  114
# 8      stop  104
# 9     repli  103
# 10    claim   98
# 11        4   97
# 12    prize   82
# 13      get   74
# 14      new   64
# 15   servic   64
# 16     tone   63
# 17     send   60
# 18   urgent   57
# 19    nokia   57
# 20  contact   56
# 21    award   55
# 22    phone   52
# 23     cash   51
# 24    pleas   51
# 25     week   49
# 26      win   48
# 27        c   45
# 28  collect   45
# 29      min   45

# %%
spam_words_df.rename(columns={0:'text',1:'quantity'},inplace=True)

# %%
spam_words_df
# Out:
#        text  quantity
# 0      call       320
# 1      free       191
# 2         2       155
# 3       txt       141
# 4      text       122
# 5         u       119
# 6        ur       119
# 7     mobil       114
# 8      stop       104
# 9     repli       103
# 10    claim        98
# 11        4        97
# 12    prize        82
# 13      get        74
# 14      new        64
# 15   servic        64
# 16     tone        63
# 17     send        60
# 18   urgent        57
# 19    nokia        57
# 20  contact        56
# 21    award        55
# 22    phone        52
# 23     cash        51
# 24    pleas        51
# 25     week        49
# 26      win        48
# 27        c        45
# 28  collect        45
# 29      min        45

# %%
sns.barplot(x=spam_words_df['text'],y=spam_words_df['quantity'])
plt.xticks(rotation='vertical')

plt.show()

# %%
ham_words=[]

for msg in df[df['Nature']==0]['transformed_text'].tolist():
    for word in msg.split():
        ham_words.append(word)

# %%
from collections import Counter
ham_words_df=pd.DataFrame(Counter(ham_words).most_common(30))

# %%
ham_words_df.rename(columns={0:'text',1:'quantity'},inplace=True)

# %%
ham_words_df
# Out:
#      text  quantity
# 0       u       883
# 1      go       404
# 2     get       349
# 3      gt       288
# 4      lt       287
# 5       2       284
# 6    come       275
# 7     got       236
# 8    know       236
# 9    like       234
# 10   call       233
# 11   time       219
# 12     ok       217
# 13   love       216
# 14   good       213
# 15   want       208
# 16     ur       197
# 17    day       190
# 18   need       170
# 19    one       165
# 20    lor       159
# 21      4       156
# 22   home       152
# 23  think       149
# 24    see       147
# 25   take       143
# 26  still       143
# 27     da       138
# 28   tell       133
# 29   make       129

# %%
sns.barplot(x=ham_words_df['text'],y=ham_words_df['quantity'])

plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=ham_words_df['text'],y=ham_words_df['quantity'])

plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
tfidf=TfidfVectorizer(max_features=3000) 
cv=CountVectorizer()

# %%
X=cv.fit_transform(df['transformed_text']).toarray()

# %%
y= df['Nature'].values

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=True)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB,CategoricalNB

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)

print('ACCURACY',accuracy_score(y_test,y_pred1))
# Out:
# ACCURACY 0.8597678916827853

# %%
mnb.fit(X_train,y_train)
y_pred1=mnb.predict(X_test)

print('ACCURACY',accuracy_score(y_test,y_pred1))
# Out:
# ACCURACY 0.9680851063829787

# %%
bnb.fit(X_train,y_train)
y_pred1=bnb.predict(X_test)

print('ACCURACY',accuracy_score(y_test,y_pred1))
# Out:
# ACCURACY 0.9545454545454546

# %%
import pickle

pickle.dump(tfidf, open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
